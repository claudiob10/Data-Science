# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# ### Read csv file and convert to Dataframe

# %%
dataframe1 = pd.read_csv('MatterRecommenderList.csv')
dataframe1= pd.DataFrame(dataframe1, columns=['matterID (2)', 'matterCode (2)', 'matterName (2)', 'matterPhaseName (2)', 'practiceAreaName (2)', 'cityName', 'MATTERCOMMENTS'])

# %% [markdown]
# ### Clean and replace null comments

# %%
dataframe1['MATTERCOMMENTS'].fillna('No Comments', inplace=True)

# %% [markdown]
# ### Save datainput and look for the information of that mattercode

# %%
datainput = "00001-00015"
dataframe2 = dataframe1.loc[dataframe1['matterCode (2)'] == datainput ]
# Out:
#     matterID (2) matterCode (2) matterName (2) matterPhaseName (2)  \
# 14            15    00001-00015     DRY V. WET              Appeal
#
#    practiceAreaName (2) cityName  \
# 14           Litigation  Chicago
#
#                                        MATTERCOMMENTS
# 14  Shelley Jane Brozek and Kirk Steven Brozek sep...

# %%
index = dataframe1.index[dataframe1['matterCode (2)'] == datainput].tolist()[0]
location=dataframe2.loc[index,'cityName']
practicearea=dataframe2.loc[index,'practiceAreaName (2)']
# Out:
# 14L

# %%
#filter data for location

data3 = dataframe1.loc[dataframe1['cityName'] == location]
    
"""if number of register if less than 5, we use the information previous filtering
if not we filter first by location, and then by practiceAreaName
we need to have at least 5 register to analyse the MATTERCOMMENTS and make a recommendation
"""    
if (len(data3.index)<5):
        
    datafinal = dataframe1
        
else:
        
    data4 = data3.loc[data3['practiceAreaName (2)'] == practicearea]
        
    if (len(data4.index)<5):
            
        datafinal=data3
            
    else:
            
        datafinal=data4

# %%
datafinal
# Out:
#     matterID (2) matterCode (2)      matterName (2)  \
# 2              3    00001-00003      VEST V. JACKET
# 5              6    00001-00006           2 V. 1 Ed
# 6              7    00001-00007     GRASS V. GRAVEL
# 7              8    00001-00008       TOP V. BOTTOM
# 8              9    00001-00009  ROCK V. HARD PLACE
# 9             10    00001-00010  HOUSE V. APARTMENT
# 10            11    00001-00011       JOB V. RETIRE
# 11            12    00001-00012        BASE V. BALL
# 12            13    00001-00013        RIDE V. WALK
# 14            15    00001-00015          DRY V. WET
# 17            18    00001-00021      BLACK V. WHITE
# 20            21    00001-00029  MOUSE V. TRACKBALL
# 21            22    00001-00030     OFFICE V. DEPOT
# 22            23    00001-00038    ORANGE V. YELLOW
# 23            24    00001-00039       PURPLE V. RED
# 24            25    00001-00040        DOGS V. CATS
# 25            26    00001-00041      LAST V. CHANCE
# 26            27    00001-00042    SPRING V. SPRUNG
# 27            28    00001-00045       PEN V. PENCIL
# 32            33    00002-00001          CAR V. BUS
# 35            36    00002-00005        FLIP V. FLOP
# 36            37    00002-00006  CHAIR V. YOGA BALL
# 37            38    00002-00008       JUMP V. SLIDE
# 38            39    00002-00013         HOT V. COLD
# 39            40    00002-00014   LAKERS V. CELTICS
#
#                                 matterPhaseName (2) practiceAreaName (2)  \
# 2   Case Assessment, Development and Administration           Litigation
# 5                                         Discovery           Litigation
# 6                   Pre-Trial Pleadings and Motions           Litigation
# 7   Case Assessment, Development and Administration           Litigation
# 8                       Trial Preparation and Trial           Litigation
# 9                   Pre-Trial Pleadings and Motions           Litigation
# 10                                        Discovery           Litigation
# 11                  Pre-Trial Pleadings and Motions           Litigation
# 12                      Trial Preparation and Trial           Litigation
# 14                                           Appeal           Litigation
# 17                                        Discovery           Litigation
# 20                                        Discovery           Litigation
# 21                  Pre-Trial Pleadings and Motions           Litigation
# 22                      Trial Preparation and Trial           Litigation
# 23  Case Assessment, Development and Administration           Litigation
# 24  Case Assessment, Development and Administration           Litigation
# 25  Case Assessment, Development and Administration           Litigation
# 26  Case Assessment, Development and Administration           Litigation
# 27  Case Assessment, Development and Administration           Litigation
# 32  Case Assessment, Development and Administration           Litigation
# 35  Case Assessment, Development and Administration           Litigation
# 36  Case Assessment, Development and Administration           Litigation
# 37                      Trial Preparation and Trial           Litigation
# 38                                           Appeal           Litigation
# 39                                           Appeal           Litigation
#
#    cityName                                     MATTERCOMMENTS
# 2   Chicago  A bank�s action against four guarantors on the...
# 5   Chicago  Following a jury trial, Rosario Betancourt-Gar...
# 6   Chicago  On the advice of a parent, who was also a scho...
# 7   Chicago                                        No Comments
# 8   Chicago  On December 1, 2014, Boche was charged with fi...
# 9   Chicago  We consider the appellees� motions for reheari...
# 10  Chicago  Shelley Jane Brozek and Kirk Steven Brozek sep...
# 11  Chicago  This case is before the court on the voluntary...
# 12  Chicago  STATEMENT OF FACTS 1. Background and Evidence ...
# 14  Chicago  Shelley Jane Brozek and Kirk Steven Brozek sep...
# 17  Chicago  The State of Oklahoma, ex rel. Oklahoma Bar As...
# 20  Chicago  After a jury trial, Robertson was convicted of...
# 21  Chicago  impression�whether a tax sale certificate issu...
# 22  Chicago  Robert W. Grant appeals from his convictions o...
# 23  Chicago  STATEMENT OF FACTS 1. Background and Evidence ...
# 24  Chicago  Courtney W. Starks, who stands convicted of fi...
# 25  Chicago  In 2013, the separate juvenile court of Dougla...
# 26  Chicago  Shelley Jane Brozek and Kirk Steven Brozek sep...
# 27  Chicago                                        No Comments
# 32  Chicago  STATEMENT OF FACTS 1. Background and Evidence ...
# 35  Chicago  Shelley Jane Brozek and Kirk Steven Brozek sep...
# 36  Chicago  This case is before the court on the condition...
# 37  Chicago  We consider the appellees� motions for reheari...
# 38  Chicago  David M. Lorenzen appeals from the property di...
# 39  Chicago  Courtney W. Starks, who stands convicted of fi...

# %%
def topNRecomendations(n, documentId, tfIdfMatrix):
    cosine_similarities = linear_kernel(tfIdfMatrix[documentId,:],tfIdfMatrix).flatten()
    related_docs_indices = cosine_similarities.argsort()[:-n-2:-1]
    return related_docs_indices[1:]

# %%
vectorizer = CountVectorizer()
vectorizer.fit_transform(datafinal['MATTERCOMMENTS'])
spTermMatrix = vectorizer.transform(datafinal['MATTERCOMMENTS'])
    
tfIdf = TfidfTransformer()
tfIdfMatrix = tfIdf.fit(spTermMatrix)
tfIdfMatrix = tfIdf.transform(spTermMatrix)

# %%
    variable = dataframe2.index[dataframe2['matterCode (2)'] == dataframe1['Col1'][0]].tolist()[0]
    matterIndex = variable
    results = []
    
    for i in range(5):
        results.append(dataframe2['matterCode (2)'].loc[topNRecomendations(5, matterIndex, tfIdfMatrix)[i]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-93849ea73b27> in <module>()
#       3 results = []
#       4 for i in range(5):
# ----> 5     results.append(datafinal['matterCode (2)'].loc[topNRecomendations(5, [15], tfIdfMatrix)[i]])
#
# C:\Users\Darwoft\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# C:\Users\Darwoft\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# C:\Users\Darwoft\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# C:\Users\Darwoft\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: u'the label [15] is not in the [index]'
